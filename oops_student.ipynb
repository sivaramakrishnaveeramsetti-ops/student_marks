# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaramakrishnaveeramsetti-ops/student_marks/blob/main/oops_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:

    def __init__(self,name,marks):
        self.name=name
        self.marks=marks

    def display(self):
        print("Student Name:",self.name)
        print("Student Marks:",self.marks)


students=[]

while True:

    name=input("Enter student name: ")
    marks=int(input("Enter student marks: "))
    duplicate=False
    for student in students:
        if student.name.lower()==name.lower():
            duplicate=True
            break

    if duplicate:
        print("Student already exists!")
    else:
     s=Student(name,marks)
     students.append(s)
     print("Student details added successfully...")

    option=input("Do you want to add another student (yes/no): ")

    if option.lower()=="no":
        break


print("Total students:",len(students))
print()

for student in students:
    student.display()
    print()
# Out:
# Enter student name: siva
# Enter student marks: 95
# Student details added successfully...
# Do you want to add another student (yes/no): yes
# Enter student name: imran
# Enter student marks: 96
# Student details added successfully...
# Do you want to add another student (yes/no): yes
# Enter student name: madhavi
# Enter student marks: 98
# Student details added successfully...
# Do you want to add another student (yes/no): yes
# Enter student name: akhila
# Enter student marks: 94
# Student details added successfully...
# Do you want to add another student (yes/no): no
# Total students: 4
#
# Student Name: siva
# Student Marks: 95
#
# Student Name: imran
# Student Marks: 96
#
# Student Name: madhavi
# Student Marks: 98
#
# Student Name: akhila
# Student Marks: 94
